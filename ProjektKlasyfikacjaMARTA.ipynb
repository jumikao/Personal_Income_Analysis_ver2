# %% [markdown]
# <a href="https://colab.research.google.com/github/jumikao/-Projekt-klasyfikacja-Asia-Marta-Justyna/blob/main/ProjektKlasyfikacjaMARTA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. DESCRIPTION
#
# Celem projektu jest zbadanie jakie czynniki wpływają na decyzję o zmianie pracy.
# Projekt jest realizowany w ramach Projektu grupowego z klasyfikacji.
# Autorzy: Asia, Marta, Justyna z grupy ARPDataPL2

# %% [markdown]
# #2. DATA COLLECTION

# %%
import pandas as pd

# %%
plik_attrition = pd.read_csv(r'https://raw.githubusercontent.com/BasiaSDA/projekt-klasyfikacja/main/attrition.csv')
plik_attrition
# Out:
#       EmployeeNumber Attrition
# 0                104        No
# 1               1638        No
# 2                164        No
# 3                395        No
# 4                 53        No
# ...              ...       ...
# 4444            7975       Yes
# 4445            7976       Yes
# 4446            7977       Yes
# 4447            7978       Yes
# 4448            7979       Yes
#
# [4449 rows x 2 columns]

# %%
plik_df1= pd.read_csv(r'https://raw.githubusercontent.com/BasiaSDA/projekt-klasyfikacja/main/df1.csv')
plik_df1
# Out:
#       EmployeeNumber     Age BusinessTravel  DailyRate  \
# 0                104    30.0  Travel_Rarely      852.0
# 1               1638    38.0  Travel_Rarely      397.0
# 2                164    26.0  Travel_Rarely      841.0
# 3                395    28.0  Travel_Rarely     1117.0
# 4                 53    35.0  Travel_Rarely      464.0
# ...              ...     ...            ...        ...
# 4444            7975  8823.0  Travel_Rarely      621.0
# 4445            7976  8823.0  Travel_Rarely      621.0
# 4446            7977    44.0     Non-Travel      381.0
# 4447            7978    44.0     Non-Travel      381.0
# 4448            7979    44.0     Non-Travel      381.0
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0     Research & Development               1.0        1.0  Life Sciences
# 1     Research & Development               2.0        2.0        Medical
# 2     Research & Development               6.0        3.0          Other
# ...

# %%
plik_df2=pd.read_csv(r'https://raw.githubusercontent.com/BasiaSDA/projekt-klasyfikacja/main/df2.csv')
plik_df2
# Out:
#       EmployeeNumber Over18 OverTime  PercentSalaryHike  PerformanceRating  \
# 0                104      Y      Yes               12.0                3.0
# 1               1638      Y      Yes               19.0                3.0
# 2                164      Y       No               19.0                3.0
# 3                395      Y       No               21.0                4.0
# 4                 53      Y       No               12.0                3.0
# ...              ...    ...      ...                ...                ...
# 4444            7975      Y       No               11.0                3.0
# 4445            7976      Y       No               11.0                3.0
# 4446            7977      Y       No               14.0                3.0
# 4447            7978      Y       No               14.0                3.0
# 4448            7979      Y       No               14.0                3.0
#
#       RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
plik_sample=pd.read_csv(r'https://raw.githubusercontent.com/BasiaSDA/projekt-klasyfikacja/main/sample_output.csv')

# %% [markdown]
# #3. DATA CLEANING

# %%
plik_attrition.describe()
# Out:
#        EmployeeNumber
# count     4449.000000
# mean      7956.865588
# std      17226.922333
# min          1.000000
# 25%       1735.000000
# 50%       5902.000000
# 75%       7014.000000
# max     100146.000000

# %%
plik_df1.describe()
# Out:
#        EmployeeNumber          Age    DailyRate  DistanceFromHome  \
# count     4449.000000  4449.000000  4449.000000       4449.000000
# mean      7956.865588   416.187458   801.017982      33339.433356
# std      17226.922333  1566.205147   405.605362     145352.131423
# min          1.000000    18.000000   102.000000          1.000000
# 25%       1735.000000    31.000000   458.000000          2.000000
# 50%       5902.000000    36.000000   804.000000          8.000000
# 75%       7014.000000    45.000000  1162.000000         17.000000
# max     100146.000000  9890.000000  1499.000000     999590.000000
#
#          Education  EmployeeCount  EnvironmentSatisfaction   HourlyRate  \
# count  4449.000000         4449.0              4449.000000  4449.000000
# mean      2.909867            1.0                 2.719263    65.977073
# std       1.025184            0.0                 1.093263    20.277369
# min       1.000000            1.0                 1.000000    30.000000
# ...

# %%
plik_df2.describe()
# Out:
#        EmployeeNumber  PercentSalaryHike  PerformanceRating  \
# count     4449.000000        4449.000000        4449.000000
# mean      7956.865588          15.187683           3.148573
# std      17226.922333           3.642842           0.355707
# min          1.000000          11.000000           3.000000
# 25%       1735.000000          12.000000           3.000000
# 50%       5902.000000          14.000000           3.000000
# 75%       7014.000000          18.000000           3.000000
# max     100146.000000          25.000000           4.000000
#
#        RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# count               4449.000000         4449.0       4449.000000
# mean                   2.725556           80.0          0.785795
# std                    1.080807            0.0          0.848038
# min                    1.000000           80.0          0.000000
# 25%                    2.000000           80.0          0.000000
# ...

# %%
plik_df2["Attrition"].describe()
# Out:
# count     4302
# unique       2
# top        Yes
# freq      2222
# Name: Attrition, dtype: object

# %%
plik_attrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4449 entries, 0 to 4448
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EmployeeNumber  4449 non-null   int64
#  1   Attrition       4302 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 69.6+ KB

# %%
plik_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4449 entries, 0 to 4448
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeNumber           4449 non-null   int64
#  1   Age                      4449 non-null   float64
#  2   BusinessTravel           4449 non-null   object
#  3   DailyRate                4449 non-null   float64
#  4   Department               4449 non-null   object
#  5   DistanceFromHome         4449 non-null   float64
#  6   Education                4449 non-null   float64
#  7   EducationField           4449 non-null   object
#  8   EmployeeCount            4449 non-null   float64
#  9   EnvironmentSatisfaction  4449 non-null   float64
#  10  Gender                   4449 non-null   object
#  11  HourlyRate               4449 non-null   float64
#  12  JobInvolvement           4449 non-null   float64
#  13  JobLevel                 4449 non-null   float64
# ...

# %%
plik_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4449 entries, 0 to 4448
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            4449 non-null   int64
#  1   Over18                    4449 non-null   object
#  2   OverTime                  4449 non-null   object
#  3   PercentSalaryHike         4449 non-null   float64
#  4   PerformanceRating         4449 non-null   float64
#  5   RelationshipSatisfaction  4449 non-null   float64
#  6   StandardHours             4449 non-null   float64
#  7   StockOptionLevel          4449 non-null   float64
#  8   TotalWorkingYears         4449 non-null   float64
#  9   TrainingTimesLastYear     4449 non-null   float64
#  10  WorkLifeBalance           4449 non-null   float64
#  11  YearsAtCompany            4449 non-null   float64
#  12  YearsInCurrentRole        4449 non-null   float64
# ...

# %% [markdown]
# ##3.1 Łączenie tabel plik_df1 i plik_df2 (Nowa tabela= merged_df)

# %%
merged_df=plik_df1.merge(plik_df2, on="EmployeeNumber", how="left")
merged_df
# Out:
#       EmployeeNumber     Age BusinessTravel  DailyRate  \
# 0                104    30.0  Travel_Rarely      852.0
# 1               1638    38.0  Travel_Rarely      397.0
# 2                164    26.0  Travel_Rarely      841.0
# 3                395    28.0  Travel_Rarely     1117.0
# 4                 53    35.0  Travel_Rarely      464.0
# ...              ...     ...            ...        ...
# 4444            7975  8823.0  Travel_Rarely      621.0
# 4445            7976  8823.0  Travel_Rarely      621.0
# 4446            7977    44.0     Non-Travel      381.0
# 4447            7978    44.0     Non-Travel      381.0
# 4448            7979    44.0     Non-Travel      381.0
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0     Research & Development               1.0        1.0  Life Sciences
# 1     Research & Development               2.0        2.0        Medical
# 2     Research & Development               6.0        3.0          Other
# ...

# %%
merged_df.describe()
# Out:
#        EmployeeNumber          Age    DailyRate  DistanceFromHome  \
# count     4449.000000  4449.000000  4449.000000       4449.000000
# mean      7956.865588   416.187458   801.017982      33339.433356
# std      17226.922333  1566.205147   405.605362     145352.131423
# min          1.000000    18.000000   102.000000          1.000000
# 25%       1735.000000    31.000000   458.000000          2.000000
# 50%       5902.000000    36.000000   804.000000          8.000000
# 75%       7014.000000    45.000000  1162.000000         17.000000
# max     100146.000000  9890.000000  1499.000000     999590.000000
#
#          Education  EmployeeCount  EnvironmentSatisfaction   HourlyRate  \
# count  4449.000000         4449.0              4449.000000  4449.000000
# mean      2.909867            1.0                 2.719263    65.977073
# std       1.025184            0.0                 1.093263    20.277369
# min       1.000000            1.0                 1.000000    30.000000
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4449 entries, 0 to 4448
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            4449 non-null   int64
#  1   Age                       4449 non-null   float64
#  2   BusinessTravel            4449 non-null   object
#  3   DailyRate                 4449 non-null   float64
#  4   Department                4449 non-null   object
#  5   DistanceFromHome          4449 non-null   float64
#  6   Education                 4449 non-null   float64
#  7   EducationField            4449 non-null   object
#  8   EmployeeCount             4449 non-null   float64
#  9   EnvironmentSatisfaction   4449 non-null   float64
#  10  Gender                    4449 non-null   object
#  11  HourlyRate                4449 non-null   float64
#  12  JobInvolvement            4449 non-null   float64
# ...

# %% [markdown]
# ##3.2 Szukanie pustych wierszy (Nan)

# %%
nan_values=merged_df["Attrition"].isna()

nan_values_true = 0
for position in nan_values:
  if position == True:
    nan_values_true +=1
print("Number of NAN values in column 'Atrittion': ", nan_values_true)

print("Udział wierszy z NAN w sumie wierszy: ", (147/4449)*100,"%")
# Out:
# Number of NAN values in column 'Atrittion':  147
# Udział wierszy z NAN w sumie wierszy:  3.3041132838840186 %

# %% [markdown]
# ##3.3 Puste wiersze- usunięcie wierszy z NAN

# %%
# merged_df2 = merged_df[merged_df["Attrition"].notna()]      #nie działa dobrze potem
merged_df3 = merged_df.dropna(how="any")
merged_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4302 entries, 0 to 4301
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     4302 non-null   int64
#  1   EmployeeNumber            4302 non-null   int64
#  2   Age                       4302 non-null   float64
#  3   BusinessTravel            4302 non-null   object
#  4   DailyRate                 4302 non-null   float64
#  5   Department                4302 non-null   object
#  6   DistanceFromHome          4302 non-null   float64
#  7   Education                 4302 non-null   float64
#  8   EducationField            4302 non-null   object
#  9   EmployeeCount             4302 non-null   float64
#  10  EnvironmentSatisfaction   4302 non-null   float64
#  11  Gender                    4302 non-null   object
#  12  HourlyRate                4302 non-null   float64
# ...

# %%
merged_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4302 entries, 0 to 4448
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            4302 non-null   int64
#  1   Age                       4302 non-null   float64
#  2   BusinessTravel            4302 non-null   object
#  3   DailyRate                 4302 non-null   float64
#  4   Department                4302 non-null   object
#  5   DistanceFromHome          4302 non-null   float64
#  6   Education                 4302 non-null   float64
#  7   EducationField            4302 non-null   object
#  8   EmployeeCount             4302 non-null   float64
#  9   EnvironmentSatisfaction   4302 non-null   float64
#  10  Gender                    4302 non-null   object
#  11  HourlyRate                4302 non-null   float64
#  12  JobInvolvement            4302 non-null   float64
# ...

# %% [markdown]
# ##3.4 Sprawdzanie duplikatów

# %%
print(any(merged_df2.duplicated()))      #brak zduplikowanych wierszy
# Out:
# False

# %% [markdown]
# ##3.5 Sprawdzenie szumów -> czy wartości mają sens

# %%
merged_df2['Age'].unique()                     #OK
merged_df2['BusinessTravel'].unique()          #OK: ['Travel_Rarely', 'Travel_Frequently', 'Non-Travel']
merged_df2['DailyRate'].unique()               #OK
merged_df2['Department'].unique()              #OK: ['Research & Development', 'Human Resources', 'Sales']
merged_df2['DistanceFromHome'].unique()        #OK
merged_df2['Education'].unique()               #OK
merged_df2['EducationField'].unique()          #OK: ['Life Sciences', 'Medical', 'Other', 'Technical Degree', 'Marketing', 'Human Resources']
merged_df2['EmployeeCount'].unique()           #!!!!!!!!kolumna do usunięcia - same 1, nic nie wnosi
merged_df2['EnvironmentSatisfaction'].unique() #OK
merged_df2['Gender'].unique()                  #OK: ['Male', 'Female']
merged_df2['HourlyRate'].unique()              #OK
merged_df2['JobInvolvement'].unique()          #OK
merged_df2['JobLevel'].unique()                #OK
merged_df2['JobRole'].unique()                 #OK: ['Laboratory Technician', 'Manufacturing Director', 'Research Scientist', 'Human Resources', 'Research Director', 'Sales Representative', 'Manager', 'Healthcare Representative', 'Sales Executive']
merged_df2['JobSatisfaction'].unique()         #OK
merged_df2['MaritalStatus'].unique()           #OK: ['Married', 'Single', 'Divorced']
merged_df2['MonthlyIncome'].unique()           #????????spr za pomocą scatter plot? isnumeric?
merged_df2['MonthlyRate'].unique()             #????????spr za pomocą scatter plot? isnumeric?
merged_df2['NumCompaniesWorked'].unique()      #OK
merged_df2['Over18'].unique()                  #!!!!!kolumna do usunięcia - same ['Y'], nic nie wnosi
merged_df2['OverTime'].unique()                #OK: ['Yes', 'No']
merged_df2['PercentSalaryHike'].unique()       #OK
merged_df2['PerformanceRating'].unique()       #OK: [3., 4.]
merged_df2['RelationshipSatisfaction'].unique() #OK
merged_df2['StandardHours'].unique()           #!!!!!!kolumna do usunięcia - same ['80'], nic nie wnosi
merged_df2['StockOptionLevel'].unique()        #OK
merged_df2['TotalWorkingYears'].unique()       #OK
merged_df2['TrainingTimesLastYear'].unique()   #OK
merged_df2['WorkLifeBalance'].unique()         #OK
merged_df2['YearsAtCompany'].unique()          #OK
merged_df2['YearsInCurrentRole'].unique()      #OK
merged_df2['YearsSinceLastPromotion'].unique() #OK
merged_df2['YearsWithCurrManager'].unique()    #OK
merged_df2['Attrition'].unique()               #OK: ['No', 'Yes']
merged_df2['YearlyIncome'].unique()            #????????spr za pomocą scatter plot? isnumeric?
# Out:
# array([ 61512.,  93072.,  28416., ..., 160176.,  95736.,  44496.])

# %% [markdown]
# Usuwanie niepotrzebnych kolumn: Over18,standardhours, employeecount

# %%
merged_df_drop= merged_df2.drop(columns=['StandardHours','EmployeeCount','Over18'])
merged_df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4302 entries, 0 to 4301
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     4302 non-null   int64
#  1   EmployeeNumber            4302 non-null   int64
#  2   Age                       4302 non-null   float64
#  3   BusinessTravel            4302 non-null   object
#  4   DailyRate                 4302 non-null   float64
#  5   Department                4302 non-null   object
#  6   DistanceFromHome          4302 non-null   float64
#  7   Education                 4302 non-null   float64
#  8   EducationField            4302 non-null   object
#  9   EnvironmentSatisfaction   4302 non-null   float64
#  10  Gender                    4302 non-null   object
#  11  HourlyRate                4302 non-null   float64
#  12  JobInvolvement            4302 non-null   float64
# ...

# %% [markdown]
# Sprawdzenie reprezentatywności danych za pomoca scatter plot dla kolumny "Monthly Income"
# Dochód osoby na m-c

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 10))
sns.distplot(merged_df_drop.MonthlyIncome)


plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Sprawdzenie reprezentatywności danych za pomoca scatter plot dla kolumny "YearlyIncome" Roczne zarobki

# %%
plt.figure(figsize=(14, 10))
sns.distplot(merged_df_drop.YearlyIncome)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Sprawdzenie reprezentatywności danych za pomoca scatter plot dla kolumny "MonthlyRate"
# Miesięczny koszt dla pracodawcy

# %%
plt.figure(figsize=(14, 10))
sns.distplot(merged_df_drop.MonthlyRate)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(14, 10))
sns.distplot(merged_df_drop.YearlyIncome)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Wnioski: zdecydowana większość osób posiada zarobki w dolnym przedziale
# Koszt dla pracodawcy rozkłada się równomiernie? Dziwne?

# %% [markdown]
# ##3.6 Zamiana wartości tekstowych na wartości numeryczne dla kolumn:
#
#
# 1. 'BusinessTravel'
# ['Travel_Rarely', 'Travel_Frequently', 'Non-Travel']
# 2. 'Department'
# ['Research & Development', 'Human Resources', 'Sales']
# 3. 'EducationField'
# ['Life Sciences', 'Medical', 'Other', 'Technical Degree', 'Marketing', 'Human Resources']
# 4. 'Gender'
# ['Male', 'Female']
# 5. 'JobRole'
# ['Laboratory Technician', 'Manufacturing Director', 'Research Scientist', 'Human Resources', 'Research Director', 'Sales Representative', 'Manager', 'Healthcare Representative', 'Sales Executive']
# 6. 'MaritalStatus'
# ['Married', 'Single', 'Divorced']
# 7. 'OverTime'
# ['Yes', 'No']
# 8. 'PerformanceRating
# [3., 4.]
# 9. 'Attrition'
# ['No', 'Yes']

# %%
#Business Travel
lista=[]
for i in range(len(merged_df_drop)):

  if merged_df_drop['BusinessTravel'][i]=="Travel_Frequently":
    lista.append(1)
  elif merged_df_drop['BusinessTravel'][i]=="Travel_Rarely":
    lista.append(2)
  else:
    lista.append(3)
merged_df_drop['BusinessTravel_encode']=lista

# %%
merged_df_drop.columns
# Out:
# Index(['index', 'EmployeeNumber', 'Age', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition',
#        'YearlyIncome', 'BusinessTravel_encode'],
#       dtype='object')

# %%
#Department
lista=[]
for i in range(len(merged_df_drop)):
  if merged_df_drop['Department'][i]=="Research & Development":
    lista.append(1)
  elif merged_df_drop['Department'][i]=="Human Resources":
    lista.append(2)
  else:
    lista.append(3)
merged_df_drop['Department_encode']=lista

# %%
merged_df_drop.columns
# Out:
# Index(['index', 'EmployeeNumber', 'Age', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition',
#        'YearlyIncome', 'BusinessTravel_encode', 'Department_encode'],
#       dtype='object')

# %%
#Education Field
lista=[]
for i in range(len(merged_df_drop)):
  if merged_df_drop['EducationField'][i]=="Life Sciences":
    lista.append(1)
  elif merged_df_drop['EducationField'][i]=="Medical":
    lista.append(2)
  elif merged_df_drop['EducationField'][i]=="Other":
    lista.append(3) 
  elif merged_df_drop['EducationField'][i]=="Technical Degree":
    lista.append(4) 
  elif merged_df_drop['EducationField'][i]=="Marketing":
    lista.append(5)  
  else:
    lista.append(6)
merged_df_drop['EducationField_encode']=lista

# %%
#Gender
lista=[]
for i in range(len(merged_df_drop)):
  if merged_df_drop['Gender'][i]=="Male":
    lista.append(1)
  else:
    lista.append(2)
merged_df_drop['Gender_encode']=lista

# %%
#OverTime
lista=[]
for i in range(len(merged_df_drop)):
  if merged_df_drop['OverTime'][i]=="No":
    lista.append(1)
  else:
    lista.append(2)
merged_df_drop['OverTime_encode']=lista

# %%
#Job Role
lista=[]
for i in range(len(merged_df_drop)):
  if merged_df_drop['JobRole'][i]=="'Laboratory Technician":
    lista.append(1)
  elif merged_df_drop['JobRole'][i]=="Manufacturing Director":
    lista.append(2)
  elif merged_df_drop['JobRole'][i]=="Research Scientist":
    lista.append(3) 
  elif merged_df_drop['JobRole'][i]=="Human Resources":
    lista.append(4) 
  elif merged_df_drop['JobRole'][i]=="Research Director":
    lista.append(5)  
  elif merged_df_drop['JobRole'][i]=="Sales Representative":
    lista.append(6)
  elif merged_df_drop['JobRole'][i]=="Manager":
    lista.append(7) 
  elif merged_df_drop['JobRole'][i]=="Healthcare Representative":
    lista.append(8) 
  else:
    lista.append(9)
merged_df_drop['JobRole_encode']=lista

# %%
#Maritial Status
lista=[]
for i in range(len(merged_df_drop)):
  if merged_df_drop['MaritalStatus'][i]=="Single":
    lista.append(1)
  elif merged_df_drop['MaritalStatus'][i]=="Married":
    lista.append(2)
  else:
    lista.append(3)
merged_df_drop['MaritalStatus_encode']=lista

# %%
#Performance Rating
lista=[]
for i in range(len(merged_df_drop)):
  if merged_df_drop['PerformanceRating'][i]=="3.":
    lista.append(1)
  else:
    lista.append(2)
merged_df_drop['PerformanceRating_encode']=lista

# %%
#Attrition
lista=[]
for i in range(len(merged_df_drop)):
  if merged_df_drop['Attrition'][i]=="Yes":
    lista.append(1)
  else:
    lista.append(2)
merged_df_drop['Attrition_encode']=lista

# %%
#FINALNA TABELA 
merged_df_drop.columns
# Out:
# Index(['index', 'EmployeeNumber', 'Age', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition',
#        'YearlyIncome', 'BusinessTravel_encode', 'Department_encode',
#        'EducationField_encode', 'Gender_encode', 'OverTime_encode',
#        'JobRole_encode', 'MaritalStatus_encode', 'PerformanceRating_encode',
#        'Attrition_encode'],
#       dtype='object')

# %%
merged_df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4302 entries, 0 to 4301
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     4302 non-null   int64
#  1   EmployeeNumber            4302 non-null   int64
#  2   Age                       4302 non-null   float64
#  3   BusinessTravel            4302 non-null   object
#  4   DailyRate                 4302 non-null   float64
#  5   Department                4302 non-null   object
#  6   DistanceFromHome          4302 non-null   float64
#  7   Education                 4302 non-null   float64
#  8   EducationField            4302 non-null   object
#  9   EnvironmentSatisfaction   4302 non-null   float64
#  10  Gender                    4302 non-null   object
#  11  HourlyRate                4302 non-null   float64
#  12  JobInvolvement            4302 non-null   float64
# ...

# %%
merged_df_drop["Attrition_encode"]
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 4297    1
# 4298    1
# 4299    1
# 4300    1
# 4301    1
# Name: Attrition_encode, Length: 4302, dtype: int64

# %% [markdown]
# # 4. DATA ENGINEERING

# %%
#liczenie korelacji między zmiennymi - count_corr
count_corr=merged_df_drop.corr()


#heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(count_corr)

# %% [markdown]
# ##4.1 Zmienne X,Y - definicja

# %%
merged_df_dropdrop= merged_df_drop.drop(columns=['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime','PerformanceRating','Attrition','index'])

# %%
merged_df_dropdrop.columns
# Out:
# Index(['EmployeeNumber', 'Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'YearlyIncome', 'BusinessTravel_encode',
#        'Department_encode', 'EducationField_encode', 'Gender_encode',
#        'OverTime_encode', 'JobRole_encode', 'MaritalStatus_encode',
#        'PerformanceRating_encode', 'Attrition_encode'],
#       dtype='object')

# %%
merged_df_dropdrop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4302 entries, 0 to 4301
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            4302 non-null   int64
#  1   Age                       4302 non-null   float64
#  2   DailyRate                 4302 non-null   float64
#  3   DistanceFromHome          4302 non-null   float64
#  4   Education                 4302 non-null   float64
#  5   EnvironmentSatisfaction   4302 non-null   float64
#  6   HourlyRate                4302 non-null   float64
#  7   JobInvolvement            4302 non-null   float64
#  8   JobLevel                  4302 non-null   float64
#  9   JobSatisfaction           4302 non-null   float64
#  10  MonthlyIncome             4302 non-null   float64
#  11  MonthlyRate               4302 non-null   float64
#  12  NumCompaniesWorked        4302 non-null   float64
# ...

# %%
merged_df_drop["Attrition_encode"].value_counts()
# Out:
# 1    2222
# 2    2080
# Name: Attrition_encode, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x= merged_df_dropdrop.loc[:,~merged_df_dropdrop.columns.isin(["Attrition_encode"])]

y= merged_df_drop["Attrition_encode"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
print("y_train: ", y_train)
# Out:
# y_train:  3053    2
# 3577    1
# 2139    1
# 1922    2
# 3702    2
#        ..
# 1033    2
# 3264    1
# 1653    1
# 2607    1
# 2732    1
# Name: Attrition_encode, Length: 3441, dtype: int64

# %%
print("x_train: ", x_train)
# Out:
# x_train:        EmployeeNumber     Age  DailyRate  DistanceFromHome  Education  \
# 3053            6731    34.0      181.0               2.0        4.0
# 3577            7255    41.0     1360.0              12.0        3.0
# 2139            5817    56.0     1443.0              11.0        5.0
# 1922            5600    26.0      703.0              28.0        2.0
# 3702            7380    37.0      504.0              10.0        3.0
# ...              ...     ...        ...               ...        ...
# 1033             399    31.0      444.0               5.0        3.0
# 3264            6942    35.0     1137.0              21.0        1.0
# 1653            5331  4988.0      144.0              10.0        1.0
# 2607            6285    49.0     1490.0               7.0        4.0
# 2732            6410    32.0      371.0              19.0        3.0
#
#       EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
print("y_train:", y_train)
# Out:
# y_train: 3053    2
# 3577    1
# 2139    1
# 1922    2
# 3702    2
#        ..
# 1033    2
# 3264    1
# 1653    1
# 2607    1
# 2732    1
# Name: Attrition_encode, Length: 3441, dtype: int64

# %%
y_train.value_counts()
# Out:
# 1    1775
# 2    1666
# Name: Attrition_encode, dtype: int64

# %% [markdown]
# # 5.MODELLING

# %% [markdown]
# ## 5.1 Regresja logistyczna

# %%
from sklearn import linear_model
from sklearn.metrics import accuracy_score, f1_score

# %%
#regresja logistyczna
logistic = linear_model.LogisticRegression()

logistic.fit(x_train, y_train)

y_train_pred = logistic.predict(x_train) 
y_test_pred = logistic.predict(x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# 0.70267131242741

# %%
print("F1 score dla regresji logistycznej: ", f1_score(y_test, y_test_pred))
# Out:
# F1 score dla regresji logistycznej:  0.7445109780439122

# %% [markdown]
# ## 5.2 Regresja logistyczna z CV

# %%
from sklearn.model_selection import cross_val_score
